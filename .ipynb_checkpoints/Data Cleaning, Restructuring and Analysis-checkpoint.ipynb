# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import seaborn as sns

# %% [markdown]
# ## Data Cleaning and restructuring

# %% [markdown]
# ### Data import

# %%
DF = pd.read_csv('EPL_2022-2023_match_data.csv')
DF.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away
# 0           2     1.21     1.44
# 1           2     1.27     2.34
# 2           0     0.59     0.49
# 3           1     0.89     1.10
# 4           0     1.86     0.24

# %% [markdown]
# ### Adding boulean columns for results, xg attempts results and whether they match

# %%
#Creating boulean columns to figure out who won
DF_result = DF.copy(deep=True)
DF_result['home_win'] = DF_result['goals_home'] > DF_result['goals_away']
DF_result['draw'] = DF_result['goals_home'] == DF_result['goals_away']
DF_result['away_win'] = DF_result['goals_away'] > DF_result['goals_home']
DF_result.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  home_win   draw  away_win
# 0           2     1.21     1.44     False  False      True
# 1           2     1.27     2.34     False   True     False
# 2           0     0.59     0.49      True  False     False
# 3           1     0.89     1.10      True  False     False
# 4           0     1.86     0.24      True  False     False

# %%
#Creating boulean columns to figure out what the expected goals result would be
DF_result ['xg_home_win'] = DF_result ['xg_home'] > DF_result ['xg_away']
DF_result ['xg_draw'] = DF_result ['xg_home'] == DF_result ['xg_away']
DF_result ['xg_away_win'] = DF_result ['xg_away'] > DF_result ['xg_home']
DF_result.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  home_win   draw  away_win  xg_home_win  \
# 0           2     1.21     1.44     False  False      True        False
# 1           2     1.27     2.34     False   True     False        False
# 2           0     0.59     0.49      True  False     False         True
# 3           1     0.89     1.10      True  False     False        False
# 4           0     1.86     0.24      True  False     False         True
#
#    xg_draw  xg_away_win
# 0    False         True
# 1    False         True
# 2    False        False
# 3    False         True
# ...

# %%
#Working out if the expected goals measure correctly shows the outcome of the game, and which way it was wrong
def compare_results(row):
    return (row['home_win'] == row['xg_home_win']) and (row['draw'] == row['xg_draw']) and (row['away_win'] == row['xg_away_win'])
DF_result['xg_matches_real'] = DF_result.apply(compare_results, axis=1)
DF_result.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  home_win   draw  away_win  xg_home_win  \
# 0           2     1.21     1.44     False  False      True        False
# 1           2     1.27     2.34     False   True     False        False
# 2           0     0.59     0.49      True  False     False         True
# 3           1     0.89     1.10      True  False     False        False
# 4           0     1.86     0.24      True  False     False         True
#
#    xg_draw  xg_away_win  xg_matches_real
# 0    False         True             True
# 1    False         True            False
# ...

# %% [markdown]
# ## Analysis

# %%
DF.describe()
# Out:
#            match_id  goals_home  goals_away     xg_home     xg_away
# count    380.000000  380.000000  380.000000  380.000000  380.000000
# mean   18391.500000    1.634211    1.218421    1.669184    1.295395
# std      109.840794    1.419944    1.183518    0.940286    0.801811
# min    18202.000000    0.000000    0.000000    0.020000    0.060000
# 25%    18296.750000    1.000000    0.000000    0.967500    0.690000
# 50%    18391.500000    1.000000    1.000000    1.540000    1.190000
# 75%    18486.250000    2.000000    2.000000    2.242500    1.720000
# max    18581.000000    9.000000    6.000000    4.920000    4.670000

# %% [markdown]
# ### Difference between xg and goals scored

# %%
#Total goals scored by home teams, away teams and total
total_goals_home = DF_result['goals_home'].sum()
total_goals_away = DF_result['goals_away'].sum()

total_goals = total_goals_home + total_goals_away

print ("Total goals scored:", total_goals)
print ("Total goals scored by home teams:",total_goals_home)
print ("Total goals scored by away teams:", total_goals_away)
# Out:
# Total goals scored: 1084
# Total goals scored by home teams: 621
# Total goals scored by away teams: 463

# %%
xg_total_home = DF_result['xg_home'].sum()
xg_total_away = DF_result['xg_away'].sum()

xg_total = xg_total_home + xg_total_away

print ("Total xg:", xg_total)
print ("Home xg:", xg_total_home)
print ("Away xg:", xg_total_away)
# Out:
# Total xg: 1126.54
# Home xg: 634.29
# Away xg: 492.24999999999994

# %%
xg_real_difference_home = total_goals_home - xg_total_home
xg_real_difference_away = total_goals_away - xg_total_away
xg_real_difference_overall = total_goals - xg_total

print ("XG vs Real Difference Total:", xg_real_difference_overall)# this many less goals were scored than chances created
print ("XG vs Real Difference Home:", xg_real_difference_home) 
print ("XG vs Real Difference Away:", xg_real_difference_away)
# Out:
# XG vs Real Difference Total: -42.539999999999964
# XG vs Real Difference Home: -13.289999999999964
# XG vs Real Difference Away: -29.249999999999943

# %% [markdown]
# ### Discrepancy

# %%
#the number of times results made by xg do not match real results
discrepancy_count = DF_result[DF_result['xg_matches_real'] == False].shape[0]
print ("Numbers of games where the real result is different to the result predicted by xg: ",discrepancy_count)
# Out:
# Numbers of games where the real result is different to the result predicted by xg:  147

# %%
#the number of times results made by xg do not match real results - not including draws
## it is highly unlikely that two teams will have the exact same XG therefore the draw probability is highly unlikely. How does this change the result?
def compare_results_no_draw(row):
    if row['draw']:  
        return True
    return (row['home_win'] == row['xg_home_win']) and (row['away_win'] == row['xg_away_win'])

DF_result['xg_matches_real_no_draw'] = DF_result.apply(compare_results_no_draw, axis=1)

discrepancy_no_draw_count = DF_result[DF_result['xg_matches_real_no_draw'] == False].shape[0]
print ("Numbers of games where the real result is different to the result predicted by xg (no draws):", discrepancy_no_draw_count)
# Out:
# Numbers of games where the real result is different to the result predicted by xg (no draws): 61

# %% [markdown]
# ### Question 1 - Is xG a good estimator of total goals scored over the entire season?

# %%
location = ("Home", "Away", "Total")
goal_type = {
    'Total Goals Scored': (total_goals_home, total_goals_away, total_goals),
    'xG': (xg_total_home, xg_total_away, xg_total)
}
x = np.arange(len(location))
width = 0.3  

fig, ax = plt.subplots(layout='constrained')

offset = width / 2 * (len(goal_type) - 1)
colors = {
    'Total Goals Scored': '#00C896',  
    'xG': '#043D3C'             
}

for i, (attribute, measurement) in enumerate(goal_type.items()):
    rects = ax.bar(x - offset + i*width, measurement, width, label=attribute, color=colors[attribute])
    ax.bar_label(rects, padding=3)

ax.set_ylabel('Total Goals Scored vs xG', fontweight="bold")
ax.set_title('Entire Season: Total Goals Scored vs xG', fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels(location)
ax.legend(loc='upper left', ncols=3)

# %% [markdown]
# ### Question 2 - Is xG a good estimator of goals scored by individual teams in a match?

# %% [markdown]
# #### Chart 1

# %%
plt.figure(figsize=(8, 5))
plt.scatter(DF_result['goals_home'], DF_result['xg_home'], color='#00C896', label='Home Goals vs XG Home', alpha = 0.05)
plt.scatter(DF_result['goals_away'], DF_result['xg_away'], color='#00C896', label='Away Goals vs XG Away',alpha = 0.05)
plt.plot([0, 6], [0, 6], color='#043D3C', linestyle='-', linewidth=1)
#Add these lines if you want to describe what happens within 1 full goals distance of xG
##Line 1 xg above the line
###plt.plot([-1, 5], [0, 6], color='#043D3C', linestyle='--', linewidth=1)
##line 1 xg below the line
###plt.plot([0, 7], [-1, 6], color='#043D3C', linestyle='--', linewidth=1)

plt.ylim(0, 6)
plt.xlim(-0.5, 9.5)
plt.xlabel('Goals Scored',fontweight="bold")
plt.ylabel('Expected Goals (xG)',fontweight="bold")
plt.title('Goals Scored vs Expected Goals ',fontweight="bold")
plt.show()
#above the trend line shows when teams have under-performed xg, below the trend line shows when teams have over-performed xg

# %% [markdown]
# #### Chart 2

# %%
#create a new dataframe to show the differences in xg for each individual team in each match
DF2 = DF.copy(deep=True)
DF2['Home_difference'] = DF2['goals_home'] - DF2['xg_home']  
DF2['Away_difference'] = DF2['goals_away'] - DF2['xg_away']
DF2
# Out:
#      match_id         teams_home               teams_away  goals_home  \
# 0       18202     Crystal Palace                  Arsenal           0
# 1       18203             Fulham                Liverpool           2
# 2       18204        Bournemouth              Aston Villa           2
# 3       18205              Leeds  Wolverhampton Wanderers           2
# 4       18206   Newcastle United        Nottingham Forest           2
# ..        ...                ...                      ...         ...
# 375     18577            Everton              Bournemouth           1
# 376     18578              Leeds                Tottenham           1
# 377     18579          Leicester                 West Ham           2
# 378     18580  Manchester United                   Fulham           2
# 379     18581        Southampton                Liverpool           4
#
#      goals_away  xg_home  xg_away  Home_difference  Away_difference
# ...

# %%
DF2_combined = pd.concat([
    DF2['Home_difference'].rename('Difference'),
    DF2['Away_difference'].rename('Difference')
], axis=0).reset_index(drop=True)

DF2_combined = pd.DataFrame(DF2_combined)
DF2_combined.describe()
# Out:
#        Difference
# count  760.000000
# mean    -0.055974
# std      1.019295
# min     -2.910000
# 25%     -0.700000
# 50%     -0.180000
# 75%      0.540000
# max      4.140000

# %%
plt.figure(figsize=(8, 5))
sns.histplot(DF2_combined['Difference'], kde=True, color="#00C896", alpha = 0.5,label='Home Difference', bins = 25)


plt.title('The Difference Between xG and Goals Scored By Individual Teams In Individual Games',fontweight="bold", size = 10)
plt.xlabel('Difference between xG and Goals Scored',fontweight="bold")
plt.ylabel('Frequency',fontweight="bold")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.figure(figsize=(8, 8))

# First subplot for Home_difference
plt.subplot(2, 1, 1) 
sns.histplot(DF2['Home_difference'], kde=True, color="#00C896", alpha=0.5, label='Home Difference', bins=20)
plt.title('The Difference Between xG and Goals Scored By Individual Teams In Individual Games (Home and Away)', fontweight='bold', size = 9)
plt.xlabel(' ', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
plt.legend()
plt.xticks(np.arange(np.floor(DF2['Home_difference'].min()), np.ceil(DF2['Home_difference'].max()) + 0.5, 0.5))

plt.subplot(2, 1, 2) 
sns.histplot(DF2['Away_difference'], kde=True, color="#043D3C", alpha=0.5, label='Away Difference', bins=20)
plt.xticks(np.arange(np.floor(DF2['Home_difference'].min()), np.ceil(DF2['Home_difference'].max()) + 0.5, 0.5))
plt.xlabel('Difference between xG and Goals Scored', fontweight='bold')
plt.ylabel('Frequency', fontweight='bold')
plt.legend()

# %% [markdown]
# ### Question 3 - How good is xG as a predictor for EPL match outcomes in the 2022/23 season?

# %%
DF_result
print ("Numbers of games where the real result is different to the result predicted by xg: ",discrepancy_count)
print ("Numbers of games where the real result is different to the result predicted by xg (no draws):", discrepancy_no_draw_count)
# Out:
# Numbers of games where the real result is different to the result predicted by xg:  147
# Numbers of games where the real result is different to the result predicted by xg (no draws): 61

# %%
Pie1_Labels = 'Correct Predictions', 'Incorrect Predictions in Games Won or Lost', 'Incorrect Predictions in Games Drawn'
Pie1_Sizes = [380 - discrepancy_count, discrepancy_no_draw_count, discrepancy_count - discrepancy_no_draw_count]
Pie1_Explode = (0.05, 0, 0)

def autopct_color(pct):
    return f'{pct:.1f}%' if pct > 0 else ''

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(Pie1_Sizes,
                                  labels=Pie1_Labels,
                                  autopct=autopct_color,
                                  colors=['#043D3C', '#00C896', '#B3CECA'],
                                  explode=Pie1_Explode,
                                  textprops={'color':"black"})

for autotext in autotexts:
    autotext.set_color('white')

plt.title('EPL 2022/23 xG Prediction Accuracy', fontweight="bold", size=10)
plt.show()

# %% [markdown]
# ### Question 4 - Rounded to the nearest goal

# %% [markdown]
# #### Creating the same structured Dataframe as for non-rounded xG

# %%
DF_result2 = DF.copy(deep=True)
DF_result2
# Out:
#      match_id         teams_home               teams_away  goals_home  \
# 0       18202     Crystal Palace                  Arsenal           0
# 1       18203             Fulham                Liverpool           2
# 2       18204        Bournemouth              Aston Villa           2
# 3       18205              Leeds  Wolverhampton Wanderers           2
# 4       18206   Newcastle United        Nottingham Forest           2
# ..        ...                ...                      ...         ...
# 375     18577            Everton              Bournemouth           1
# 376     18578              Leeds                Tottenham           1
# 377     18579          Leicester                 West Ham           2
# 378     18580  Manchester United                   Fulham           2
# 379     18581        Southampton                Liverpool           4
#
#      goals_away  xg_home  xg_away
# 0             2     1.21     1.44
# 1             2     1.27     2.34
# ...

# %%
DF_result2['xg_home_rounded'] = DF_result2['xg_home'].round()
DF_result2['xg_away_rounded'] = DF_result2['xg_away'].round()
DF_result2.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded  xg_away_rounded
# 0           2     1.21     1.44              1.0              1.0
# 1           2     1.27     2.34              1.0              2.0
# 2           0     0.59     0.49              1.0              0.0
# 3           1     0.89     1.10              1.0              1.0
# 4           0     1.86     0.24              2.0              0.0

# %%
DF_result2['home_win'] = DF_result2['goals_home'] > DF_result2['goals_away']
DF_result2['draw'] = DF_result2['goals_home'] == DF_result2['goals_away']
DF_result2['away_win'] = DF_result2['goals_away'] > DF_result2['goals_home']
DF_result2.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded  xg_away_rounded  home_win  \
# 0           2     1.21     1.44              1.0              1.0     False
# 1           2     1.27     2.34              1.0              2.0     False
# 2           0     0.59     0.49              1.0              0.0      True
# 3           1     0.89     1.10              1.0              1.0      True
# 4           0     1.86     0.24              2.0              0.0      True
#
#     draw  away_win
# 0  False      True
# 1   True     False
# 2  False     False
# 3  False     False
# ...

# %%
DF_result2 ['xg_home_rounded_win'] = DF_result2 ['xg_home_rounded'] > DF_result2 ['xg_away_rounded']
DF_result2 ['xg_rounded_draw'] = DF_result2 ['xg_home_rounded'] == DF_result2 ['xg_away_rounded']
DF_result2 ['xg_away_rounded_win'] = DF_result2 ['xg_away_rounded'] > DF_result2 ['xg_home_rounded']
DF_result2.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded  xg_away_rounded  home_win  \
# 0           2     1.21     1.44              1.0              1.0     False
# 1           2     1.27     2.34              1.0              2.0     False
# 2           0     0.59     0.49              1.0              0.0      True
# 3           1     0.89     1.10              1.0              1.0      True
# 4           0     1.86     0.24              2.0              0.0      True
#
#     draw  away_win  xg_home_rounded_win  xg_rounded_draw  xg_away_rounded_win
# ...

# %%
#Working out if the expected goals measure correctly shows the outcome of the game, and which way it was wrong
def compare_results2(row):
    return (row['home_win'] == row['xg_home_rounded_win']) and (row['draw'] == row['xg_rounded_draw']) and (row['away_win'] == row['xg_away_rounded_win'])
DF_result2['xg_rounded_matches_real'] = DF_result2.apply(compare_results2, axis=1)
DF_result2.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded  xg_away_rounded  home_win  \
# 0           2     1.21     1.44              1.0              1.0     False
# 1           2     1.27     2.34              1.0              2.0     False
# 2           0     0.59     0.49              1.0              0.0      True
# 3           1     0.89     1.10              1.0              1.0      True
# 4           0     1.86     0.24              2.0              0.0      True
#
#     draw  away_win  xg_home_rounded_win  xg_rounded_draw  xg_away_rounded_win  \
# ...

# %% [markdown]
# ### Discrepancy - rounded xG

# %%
#the number of times results made by xg do not match real results 
discrepancy_count2 = DF_result2[DF_result2['xg_rounded_matches_real'] == False].shape[0]
print ("Numbers of games where the real result is different to the result predicted by rounded xG: ",discrepancy_count2)
# Out:
# Numbers of games where the real result is different to the result predicted by rounded xG:  155

# %%
def compare_results_no_draw2(row):
    if row['draw']:  
        return True
    return (row['home_win'] == row['xg_home_rounded_win']) and (row['away_win'] == row['xg_away_rounded_win'])

DF_result2['xg_rounded_matches_real_no_draw'] = DF_result2.apply(compare_results_no_draw2, axis=1)

discrepancy_no_draw_count2 = DF_result2[DF_result2['xg_rounded_matches_real_no_draw'] == False].shape[0]
print ("Numbers of games where the real result is different to the result predicted by rounded xG (no draws):", discrepancy_no_draw_count2)
# Out:
# Numbers of games where the real result is different to the result predicted by rounded xG (no draws): 109

# %%
def autopct_color(pct):
    return f'{pct:.1f}%' if pct > 0 else ''

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(Pie2_Sizes,
                                  labels=Pie2_Labels,
                                  autopct=autopct_color,
                                  colors=['#043D3C', '#00C896', '#B3CECA'],
                                  explode=Pie2_Explode,
                                  textprops={'color':"black"})

for autotext in autotexts:
    autotext.set_color('white')

plt.title('EPL 2022/23 xG Prediction Accuracy (Rounded to the nearest whole goal)', fontweight="bold", size=10)
plt.show()

# %% [markdown]
# ### Question 4b - rounded to half a goal

# %%
DF_result3 = DF.copy(deep=True)
DF_result3
# Out:
#      match_id         teams_home               teams_away  goals_home  \
# 0       18202     Crystal Palace                  Arsenal           0
# 1       18203             Fulham                Liverpool           2
# 2       18204        Bournemouth              Aston Villa           2
# 3       18205              Leeds  Wolverhampton Wanderers           2
# 4       18206   Newcastle United        Nottingham Forest           2
# ..        ...                ...                      ...         ...
# 375     18577            Everton              Bournemouth           1
# 376     18578              Leeds                Tottenham           1
# 377     18579          Leicester                 West Ham           2
# 378     18580  Manchester United                   Fulham           2
# 379     18581        Southampton                Liverpool           4
#
#      goals_away  xg_home  xg_away
# 0             2     1.21     1.44
# 1             2     1.27     2.34
# ...

# %%
DF_result3['xg_home_rounded3'] = (DF_result3['xg_home'] * 2).round() / 2
DF_result3['xg_away_rounded3'] = (DF_result3['xg_away'] * 2).round() / 2
DF_result3.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded3  xg_away_rounded3
# 0           2     1.21     1.44               1.0               1.5
# 1           2     1.27     2.34               1.5               2.5
# 2           0     0.59     0.49               0.5               0.5
# 3           1     0.89     1.10               1.0               1.0
# 4           0     1.86     0.24               2.0               0.0

# %%
DF_result3['home_win'] = DF_result3['goals_home'] > DF_result3['goals_away']
DF_result3['draw'] = DF_result3['goals_home'] == DF_result3['goals_away']
DF_result3['away_win'] = DF_result3['goals_away'] > DF_result3['goals_home']
DF_result3.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded3  xg_away_rounded3  home_win  \
# 0           2     1.21     1.44               1.0               1.5     False
# 1           2     1.27     2.34               1.5               2.5     False
# 2           0     0.59     0.49               0.5               0.5      True
# 3           1     0.89     1.10               1.0               1.0      True
# 4           0     1.86     0.24               2.0               0.0      True
#
#     draw  away_win
# 0  False      True
# 1   True     False
# 2  False     False
# ...

# %%
DF_result3 ['xg_home_rounded3_win'] = DF_result3 ['xg_home_rounded3'] > DF_result3 ['xg_away_rounded3']
DF_result3 ['xg_rounded3_draw'] = DF_result3 ['xg_home_rounded3'] == DF_result3 ['xg_away_rounded3']
DF_result3 ['xg_away_rounded3_win'] = DF_result3 ['xg_away_rounded3'] > DF_result3 ['xg_home_rounded3']
DF_result3.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded3  xg_away_rounded3  home_win  \
# 0           2     1.21     1.44               1.0               1.5     False
# 1           2     1.27     2.34               1.5               2.5     False
# 2           0     0.59     0.49               0.5               0.5      True
# 3           1     0.89     1.10               1.0               1.0      True
# 4           0     1.86     0.24               2.0               0.0      True
#
#     draw  away_win  xg_home_rounded3_win  xg_rounded3_draw  \
# ...

# %%
def compare_results3(row):
    return (row['home_win'] == row['xg_home_rounded3_win']) and (row['draw'] == row['xg_rounded3_draw']) and (row['away_win'] == row['xg_away_rounded3_win'])
DF_result3['xg_rounded3_matches_real'] = DF_result3.apply(compare_results3, axis=1)
DF_result3.head()
# Out:
#    match_id        teams_home               teams_away  goals_home  \
# 0     18202    Crystal Palace                  Arsenal           0
# 1     18203            Fulham                Liverpool           2
# 2     18204       Bournemouth              Aston Villa           2
# 3     18205             Leeds  Wolverhampton Wanderers           2
# 4     18206  Newcastle United        Nottingham Forest           2
#
#    goals_away  xg_home  xg_away  xg_home_rounded3  xg_away_rounded3  home_win  \
# 0           2     1.21     1.44               1.0               1.5     False
# 1           2     1.27     2.34               1.5               2.5     False
# 2           0     0.59     0.49               0.5               0.5      True
# 3           1     0.89     1.10               1.0               1.0      True
# 4           0     1.86     0.24               2.0               0.0      True
#
#     draw  away_win  xg_home_rounded3_win  xg_rounded3_draw  \
# ...

# %%
discrepancy_count3 = DF_result3[DF_result3['xg_rounded3_matches_real'] == False].shape[0]
print ("Numbers of games where the real result is different to the result predicted by rounded xG: ",discrepancy_count3)
# Out:
# Numbers of games where the real result is different to the result predicted by rounded xG:  147

# %%
def compare_results_no_draw3(row):
    if row['draw']:  
        return True
    return (row['home_win'] == row['xg_home_rounded3_win']) and (row['away_win'] == row['xg_away_rounded3_win'])

DF_result3['xg_rounded3_matches_real_no_draw'] = DF_result3.apply(compare_results_no_draw3, axis=1)

discrepancy_no_draw_count3 = DF_result3[DF_result3['xg_rounded3_matches_real_no_draw'] == False].shape[0]
print ("Numbers of games where the real result is different to the result predicted by rounded xG (no draws):", discrepancy_no_draw_count3)
# Out:
# Numbers of games where the real result is different to the result predicted by rounded xG (no draws): 77

# %%
import matplotlib.pyplot as plt

Pie3_Labels = 'Correct Predictions', 'Incorrect Predictions in Games Won or Lost', 'Incorrect Predictions in Games Drawn'
Pie3_Sizes = [380 - discrepancy_count3, discrepancy_no_draw_count3, discrepancy_count3 - discrepancy_no_draw_count3]
Pie3_Explode = (0.05, 0, 0)

def autopct_color(pct):
    return f'{pct:.1f}%' if pct > 0 else ''

fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(Pie3_Sizes,
                                  labels=Pie3_Labels,
                                  autopct=autopct_color,
                                  colors=['#043D3C', '#00C896', '#B3CECA'],
                                  explode=Pie3_Explode,
                                  textprops={'color':"black"})

for autotext in autotexts:
    autotext.set_color('white')

plt.title('EPL 2022/23 xG Prediction Accuracy (Rounded to the nearest half-goal)', fontweight="bold", size=10)
plt.show()

# %% [markdown]
# #### Subplot combining rounding to 1 and 0.5 goals

# %%
Pie_Explode = (0.05, 0, 0)

def autopct_color(pct):
    return f'{pct:.1f}%' if pct > 0 else ''

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# First pie chart
wedges1, texts1, autotexts1 = ax1.pie(Pie2_Sizes,
                                     labels=Pie2_Labels,
                                     autopct=autopct_color,
                                     colors=['#043D3C', '#00C896', '#B3CECA'],
                                     explode=Pie_Explode,
                                     textprops={'color': "black"})
for autotext in autotexts1:
    autotext.set_color('white')
ax1.set_title('Rounded to the nearest goal', fontweight="bold", size=10)

# Second pie chart
wedges2, texts2, autotexts2 = ax2.pie(Pie3_Sizes,
                                     labels=Pie3_Labels,
                                     autopct=autopct_color,
                                     colors=['#043D3C', '#00C896', '#B3CECA'],
                                     explode=Pie_Explode,
                                     textprops={'color': "black"})
for autotext in autotexts2:
    autotext.set_color('white')
ax2.set_title('Rounded to the nearest half-goal', fontweight="bold", size=10)

# Set overall title for the figure
fig.suptitle('EPL 2022/23 xG Prediction Accuracy', fontweight="bold", size=14)

# Show the plot
plt.show()
